# %%
import numpy as np 
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
S = 100 
K = 100
r = 0.03 
sigma = 0.25

N = 1000
T = 1
dt = T / N
t = np.linspace(1e-5, 1 - 1e-5, N)

rv = np.random.normal(0, sigma, N)

# %%
stock_process = np.zeros(N)

B = np.cumsum(rv * np.sqrt(dt))
stock_process = 100 * np.exp((r - 0.5 * sigma**2) * dt + sigma * B)

# %%
def d1(S, K, T, r, sigma):
    
    return (np.log(S / K) + (r + sigma**2 / 2) * T) / (sigma * np.sqrt(T))

def d2(S, K, T, r, sigma):
    
    return d1(S, K, T, r, sigma) - sigma * np.sqrt(T)

def bs_call(S, K, T, r, sigma):
    
    return S * norm.cdf(d1(S, K, T, r, sigma)) - K * np.exp(-r * T) * norm.cdf(d2(S, K, T, r, sigma))

def get_delta(S, K, T, r, sigma):
    
    return norm.cdf(d1(S, K, T, r, sigma))

# %%
price = np.zeros(N)

for i in range(N): 
    
    price[i] = bs_call(stock_process[i], K, 1 - t[i], r, sigma)

# %%
delta = np.zeros(N)

for i in range(N): 
    
    delta[i] = get_delta(stock_process[i], K, 1 - t[i], r, sigma)

# %% [markdown]
# ## Start at Initial Option Price

# %%
pi_process = np.zeros(N)
pi_process[0] = price[0]
print("Initial Price: ", price[0])
# Out:
# Initial Price:  11.443985539555534

# %%
y = np.zeros(N)
y[0] = price[0] - (delta[0] * stock_process[0])

for i in range(1, N):
    
    pi_process[i] = (delta[i] * stock_process[i]) + (y[i - 1] * np.exp(-r * dt))
    y[i] = price[i] - (delta[i] * stock_process[i])

# %%
plt.plot(pi_process, label = "Delta Hedge")
plt.plot(price, label = "Option Price")
plt.title("Delta Hedge")
plt.legend(loc = 'best')
plt.show()

# %%
print("Option Price: ", price[-1])
print("Hedging Process: ", pi_process[-1])
# Out:
# Option Price:  4.3373014882417635
# Hedging Process:  4.3433143681454
