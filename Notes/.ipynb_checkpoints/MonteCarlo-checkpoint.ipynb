# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Monte Carlo Methods

# %%
N = 10000

mu = 0
sigma = 0.3
dt = 1 / N

euler = np.zeros(N)
analytic = np.zeros(N)
rv = np.random.normal(mu, sigma, N)

# %%
# Set Initial Value
euler[0] = 100
analytic[0] = 100

for i in range(1, N):
    
    euler[i] = euler[i - 1] + (mu * euler[i - 1] * dt) + (rv[i] * euler[i - 1] * np.sqrt(dt))
    analytic[i] = euler[i - 1] * np.exp((mu - 0.5 * sigma**2) * dt + sigma * rv[i] * np.sqrt(dt))

# %%
plt.plot(euler, label = "Euler Method")
plt.plot(analytic, label = "Analytic Solution")
plt.title("Monte Carlo Path")
# Out:
# Text(0.5, 1.0, 'Monte Carlo Path')

# %%
plt.plot(analytic - euler)
plt.title("Residual")
# Out:
# Text(0.5, 1.0, 'Residual')

# %% [markdown]
# ## Variation of Brownian Motion

# %%
def get_total_varitation(arr):
    
    L = len(arr)
    variation = 0
    
    for i in range(L - 1):
        variation += np.abs(arr[i + 1] - arr[i])
        
    return variation

# %%
def get_quadratic_variation(arr):
    
    L = len(arr)
    variation = 0
    
    for i in range(L - 1):
        variation += (arr[i + 1] - arr[i])**2
        
    return variation

# %%
T = 1
dt = np.array([0.1, 0.01, 0.001, 0.0001])

# %%
L = len(dt)
myData = []

for i in range(L):
    
    n = int(T / dt[i])
    discrete = np.zeros(n)
    discrete[0] = 100
    rv = np.random.normal(mu, sigma, n)
    
    for j in range(1, n):
        discrete[j] = discrete[j - 1] + (mu * discrete[j - 1] * dt[i]) + (rv[j] * discrete[j - 1] * np.sqrt(dt[i]))
        
    myData.append(discrete)

# %%
plt.plot(myData[0])

# %%
total_variation = get_total_varitation(myData[0])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[0])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  37.60741941486732
# Quadratic Variation:  221.96773608722418

# %%
plt.plot(myData[1])

# %%
total_variation = get_total_varitation(myData[1])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[1])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  240.74526341581642
# Quadratic Variation:  904.2091875883352

# %%
plt.plot(myData[2])

# %%
total_variation = get_total_varitation(myData[2])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[2])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  700.8030585846373
# Quadratic Variation:  776.009054245999

# %%
plt.plot(myData[3])

# %%
total_variation = get_total_varitation(myData[3])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[3])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  2109.0406772548663
# Quadratic Variation:  701.9587933500403

# %% [markdown]
# ## Variation of Trig Functions

# %%
from scipy import integrate

# %%
def my_function(x):
    
    return np.abs(np.cos(x))

# %%
x = np.linspace(0, 1, N)
y1 = my_function(x)
integral = integrate.simpson(y1, x)

print("Integral: ", integral)
# Out:
# Integral:  0.8414709848078322

# %%
T = 1
dt = np.array([0.1, 0.01, 0.001, 0.0001])

# %%
L = len(dt)
myData = []

for i in range(L):
    
    n = int(T / dt[i])
    discrete = np.zeros(n)
    start = 0
    
    for j in range(1, n):
        discrete[j] = np.sin(start)
        start += dt[i]
    
    myData.append(discrete)

# %%
plt.plot(myData[0])

# %%
total_variation = get_total_varitation(myData[0])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[0])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  0.7173560908995227
# Quadratic Variation:  0.06497686314743864

# %%
plt.plot(myData[1])

# %%
total_variation = get_total_varitation(myData[1])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[1])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  0.8304973704919708
# Quadratic Variation:  0.007213007244205972

# %%
plt.plot(myData[2])

# %%
total_variation = get_total_varitation(myData[2])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[2])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  0.8403886979751549
# Quadratic Variation:  0.0007267386612357085

# %%
plt.plot(myData[3])

# %%
total_variation = get_total_varitation(myData[3])
print("Total Variation: ", total_variation)

quadratic_variation = get_quadratic_variation(myData[3])
print("Quadratic Variation: ", quadratic_variation)
# Out:
# Total Variation:  0.8413629075179729
# Quadratic Variation:  7.272659529758149e-05

# %% [markdown]
# ## Ito Formula

# %% [markdown]
# ## Compute Integral of Differentiable Function

# %%
T = 1
N = 10000

# %%
def ft(t):
    
    return t**2

# %%
integral = 0
X = np.linspace(0, T, N)
Y = ft(X)
rv = np.random.normal(0, 1, N)

plt.plot(Y * rv)
plt.show()

# %%
for i in range(N):
    
    integral += Y[i] * rv[i]
    
print("Integral: ", integral)
# Out:
# Integral:  -6.041143097786689

# %% [markdown]
# ## Generate Brownian Motion Paths

# %%
bm = []
dW = []

for i in range(5):
    
    Wt = np.zeros(N)
    rv = np.random.normal(0, 1, N)
    Wt[0] = rv[0]
    dW .append(rv)
    
    for j in range(1, N):
            
        Wt[j] = Wt[j - 1] + rv[j]
        
    bm.append(Wt)
        
plt.plot(bm[0])
plt.plot(bm[1])
plt.plot(bm[2])
plt.plot(bm[3])
plt.plot(bm[4])
plt.title("Brownian Motion Paths")
plt.show()

# %% [markdown]
# ## Compute Integral with Left Hand Side

# %%
for i in range(5):
    
    integral = 0
    sum1 = 0
    
    for j in range(N - 1):
        
        integral += bm[i][j] * dW[i][j]
        sum1 += 0.5 * (bm[i][j]**2 - T)
        
    print("Ito Integral: ", integral)
    print("Integral 1: ", sum1)
    print("\n")
# Out:
# Ito Integral:  1350.5562403239398
# Integral 1:  119094.78760435063
#
#
# Ito Integral:  517.827768615049
# Integral 1:  54265.80169115482
#
#
# Ito Integral:  709.3806643379318
# Integral 1:  37004.27975941163
#
#
# Ito Integral:  706.3333216638482
# Integral 1:  112906.79356800036
#
#
# Ito Integral:  544.7167607645085
# Integral 1:  40795.74548531526

# %% [markdown]
# ## Compute Integral with Midpoint

# %%
for i in range(5):
    
    midpoint = 0
    sum1 = 0
    sum2 = 0
    
    for j in range(N - 1):
        
        midpoint += 0.5 * (bm[i][j+1] + bm[i][j]) * (bm[i][j + 1] - bm[i][j])
        sum1 += 0.5 * (bm[i][j]**2 - T)
        sum2 += 0.5 * bm[i][j]**2
        
    print("Midpoint Integral: ", midpoint)
    print("Integral 1: ", sum1)
    print("Integral 2: ", sum2)
    print("\n")
# Out:
# Midpoint Integral:  1168.6541343302442
# Integral 1:  356389.17631212046
# Integral 2:  356888.67631212046
#
#
# Midpoint Integral:  96.52582487231814
# Integral 1:  23043.875118998112
# Integral 2:  23543.375118998123
#
#
# Midpoint Integral:  802.002218050339
# Integral 1:  864134.3678663558
# Integral 2:  864633.8678663558
#
#
# Midpoint Integral:  111.12770937783499
# Integral 1:  29903.46564948302
# Integral 2:  30402.965649483027
#
#
# Midpoint Integral:  633.5326286224127
# Integral 1:  528052.3999989791
# Integral 2:  528551.8999989791

# %% [markdown]
# ## Compute Integral for Sin(t)

# %% [markdown]
# ## Ito Integral

# %%
def ft(t):
    
    return np.exp(t)

# %%
T = 1
N = 10000
rv = np.random.normal(mu, sigma, N)
t = np.linspace(0, 1, N)

ito_process = ft(t) * rv

# %%
plt.hist(ito_process, density = True, bins = 100)
plt.show()

# %%
# Lets Check the Results 
std = np.std(ito_process)
print("Standard Deviation of Ito Process: ", std)
# Out:
# Standard Deviation of Ito Process:  0.5368438019983582
